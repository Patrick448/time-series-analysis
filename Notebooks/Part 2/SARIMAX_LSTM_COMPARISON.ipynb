# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_lstm =  pd.read_csv('../../experiments/exp_test_2025-06-01/pred_ref/pred_553.csv', parse_dates=True, index_col='dt')
df_lstm
# Out:
#                                   0         1         2         3         4  \
# dt
# 2022-03-27 00:00:00+00:00  0.699478  0.711965  0.680503  0.674166  0.627441
# 2022-04-03 00:00:00+00:00  0.711914  0.724161  0.679760  0.680932  0.666012
# 2022-04-10 00:00:00+00:00  0.674719  0.695211  0.653713  0.647502  0.651594
# 2022-04-17 00:00:00+00:00  0.651688  0.687076  0.637105  0.623541  0.624720
# 2022-04-24 00:00:00+00:00  0.610769  0.627181  0.598910  0.596838  0.585520
# ...                             ...       ...       ...       ...       ...
# 2023-10-08 00:00:00+00:00  0.438631  0.439478  0.427635  0.437478  0.457078
# 2023-10-15 00:00:00+00:00  0.443889  0.443616  0.437018  0.445719  0.464837
# 2023-10-22 00:00:00+00:00  0.453001  0.465299  0.456399  0.462147  0.463652
# 2023-10-29 00:00:00+00:00  0.491935  0.492427  0.491256  0.482494  0.500566
# 2023-11-05 00:00:00+00:00  0.526999  0.518184  0.527570  0.507958  0.532235
#
#                                   5         6         7
# dt
# 2022-03-27 00:00:00+00:00  0.700446  0.734292  0.646636
# 2022-04-03 00:00:00+00:00  0.698874  0.724527  0.681559
# 2022-04-10 00:00:00+00:00  0.673114  0.721469  0.668951
# 2022-04-17 00:00:00+00:00  0.652119  0.683669  0.642835
# 2022-04-24 00:00:00+00:00  0.617801  0.635306  0.620782
# ...                             ...       ...       ...
# 2023-10-08 00:00:00+00:00  0.445836  0.481046  0.466211
# 2023-10-15 00:00:00+00:00  0.451278  0.496831  0.476331
# 2023-10-22 00:00:00+00:00  0.468169  0.502943  0.493596
# 2023-10-29 00:00:00+00:00  0.504618  0.528152  0.528789
# 2023-11-05 00:00:00+00:00  0.522328  0.544939  0.548162
#
# [85 rows x 8 columns]

# %%
sarimax_df =  pd.read_csv('pred_ref.csv', parse_dates=True, index_col='dt')
merged = pd.merge(sarimax_df, df_lstm, on='dt', how='left')
merged[['pred', 'ref', '0', '7']].plot()
# Out:
# <Axes: xlabel='dt'>

# %%
df_lstm.plot()
df_sarimax.plot()
# Out:
# <Axes: xlabel='dt'>
