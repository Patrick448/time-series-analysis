# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../processed_data/price_weather_weekly_df-2016-2023.csv', index_col='dt', parse_dates=True)
data.drop(columns=['first_day_week'], inplace=True)
data
# Out:
#                            Alface Americana - Roça  Alface Crespa - Roça  \
# dt
# 2016-04-24 00:00:00+00:00                 0.592500              0.616500
# 2016-05-01 00:00:00+00:00                 1.000000              0.426111
# 2016-05-08 00:00:00+00:00                 1.041667              0.437778
# 2016-05-15 00:00:00+00:00                 1.055833              0.430556
# 2016-05-22 00:00:00+00:00                 0.764167              0.444444
# ...                                            ...                   ...
# 2023-12-03 00:00:00+00:00                 1.875000              0.750000
# 2023-12-10 00:00:00+00:00                 1.458333              0.677083
# 2023-12-17 00:00:00+00:00                 1.125000              0.562500
# 2023-12-24 00:00:00+00:00                 1.125000              0.562500
# 2023-12-31 00:00:00+00:00                 1.166667              0.625000
#
#                            Alface Lisa - Roça  Alface Americana - Atacado  \
# dt
# ...

# %%
for col in data.columns:
    #data[col] = data[col].rolling(window=16).sum()
    data[col].plot(figsize=(15, 6))
    plt.title(col)
    plt.show()
